# %%
from azureml.core import Workspace
ws = Workspace.from_config()

dataset = Dataset.get_by_name(workspace, name='Clientes')
Customer = dataset.to_pandas_dataframe()

# %%
Customer = Customer[~Customer.isna()]

# %%
Customer
# Out:
#        CodigoCliente Titulo PrimeiroNome UltimoNome  Idade       Sexo  \
# 0                1.0   Sra.     Fernanda    Camargo   32.0   Feminino
# 1                2.0    Sr.        Paulo       Dias   63.0  Masculino
# 2                3.0    Sr.         Enzo     Araujo   64.0  Masculino
# 3                4.0    Sr.       Martim      Souza   59.0  Masculino
# 4                5.0    Sr.      Gabriel     Barros   21.0  Masculino
# ...              ...    ...          ...        ...    ...        ...
# 10004         9995.0    Sr.         Luís     Araujo   35.0  Masculino
# 10005         9996.0    Sr.       Danilo       Lima   55.0  Masculino
# 10006         9997.0   Sra.       Rebeca    Barbosa   28.0   Feminino
# 10007         9998.0   Sra.      Larissa    Martins   61.0   Feminino
# 10008         9999.0   Sra.        Clara       Dias   49.0   Feminino
#
#                                  Endereco               Cidade  UF  \
# ...
